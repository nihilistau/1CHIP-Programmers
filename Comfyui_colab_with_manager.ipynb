# %% [markdown]
# <a href="https://colab.research.google.com/github/nihilistau/1CHIP-Programmers/blob/master/Comfyui_colab_with_manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Git clone the repo and install the requirements. (ignore the pip errors about protobuf)

# %%
# #@title Environment Setup

from pathlib import Path

OPTIONS = {}

USE_GOOGLE_DRIVE = True  #@param {type:"boolean"}
UPDATE_COMFY_UI = False  #@param {type:"boolean"}
USE_COMFYUI_MANAGER = True  #@param {type:"boolean"}
INSTALL_CUSTOM_NODES_DEPENDENCIES = True  #@param {type:"boolean"}
OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI
OPTIONS['USE_COMFYUI_MANAGER'] = USE_COMFYUI_MANAGER
OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES'] = INSTALL_CUSTOM_NODES_DEPENDENCIES

current_dir = !pwd
WORKSPACE = f"{current_dir[0]}/ComfyUI"

if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /

    from google.colab import drive
    drive.mount('/content/drive')

    WORKSPACE = "/content/drive/MyDrive/ComfyUI"
    # %cd /content/drive/MyDrive

![ ! -d $WORKSPACE ] && echo -= Initial setup ComfyUI =- && git clone https://github.com/comfyanonymous/ComfyUI
# %cd $WORKSPACE

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo -= Updating ComfyUI =-
  # !git pull

# !echo -= Install dependencies =-
#updated 11th December 2023
#Remove cu121 as it causes issues in Colab.
#!pip install xformers!=0.0.18 -r requirements.txt --extra-index-url https://download.pytorch.org/whl/cu121 --extra-index-url https://download.pytorch.org/whl/cu118 --extra-index-url https://download.pytorch.org/whl/cu117
#!pip3 install accelerate
#!pip3 install einops transformers>=4.25.1 safetensors>=0.3.0 aiohttp pyyaml Pillow scipy tqdm psutil
#!pip3 install xformers!=0.0.18 torch==2.1.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
#!pip3 install torchsde

# !echo -= Install dependencies =-
# !pip3 install accelerate
# !pip3 install einops transformers>=4.28.1 safetensors>=0.4.2 aiohttp pyyaml Pillow scipy tqdm psutil tokenizers>=0.13.3
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip3 install torchsde
# !pip3 install kornia>=0.7.1 spandrel soundfile sentencepiece


if OPTIONS['USE_COMFYUI_MANAGER']:
  # %cd custom_nodes
  ![ ! -d ComfyUI-Manager ] && echo -= Initial setup ComfyUI-Manager =- && git clone https://github.com/ltdrdata/ComfyUI-Manager
  # %cd ComfyUI-Manager
  # !git pull

# %cd $WORKSPACE

if OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES']:
  # !pwd
  # !echo -= Install custom nodes dependencies =-
  ![ -f "custom_nodes/ComfyUI-Manager/scripts/colab-dependencies.py" ] && python "custom_nodes/ComfyUI-Manager/scripts/colab-dependencies.py"
print("\nAll done\n")
# Out:
# Mounting Google Drive...
# /
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# /content/drive/MyDrive/ComfyUI
# -= Install dependencies =-
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.8.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.10.5)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting xformers!=0.0.18
#   Downloading https://download.pytorch.org/whl/cu118/xformers-0.0.31.post1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# ERROR: Could not find a version that satisfies the requirement torch==2.1.0 (from versions: 2.2.0+cu118, 2.2.1+cu118, 2.2.2+cu118, 2.3.0+cu118, 2.3.1+cu118, 2.4.0+cu118, 2.4.1+cu118, 2.5.0+cu118, 2.5.1+cu118, 2.6.0+cu118, 2.7.0+cu118, 2.7.1+cu118)
# ERROR: No matching distribution found for torch==2.1.0
# Requirement already satisfied: torchsde in /usr/local/lib/python3.12/dist-packages (0.2.6)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.12/dist-packages (from torchsde) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from torchsde) (1.16.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from torchsde) (2.8.0+cu126)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from torchsde) (0.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0->torchsde) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6.0->torchsde) (3.0.3)
# /content/drive/MyDrive/ComfyUI/custom_nodes
# /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
# Already up to date.
# /content/drive/MyDrive/ComfyUI
# /content/drive/MyDrive/ComfyUI
# -= Install custom nodes dependencies =-
# ## Install dependencies for 'ComfyUI-Manager'
# ## Install dependencies for 'cg-use-everywhere'
# ## Install dependencies for 'comfyui-detail-daemon'
# ## Install dependencies for 'comfyui-impact-subpack'
# ## Install dependencies for 'comfyui-impact-pack'
# ## Install dependencies for 'rgthree-comfy'
# ## Install dependencies for 'comfyui_essentials'
# ## Install dependencies for 'ComfyUI_Comfyroll_CustomNodes'
# ## Install dependencies for 'comfy-mtb'
# ## Install dependencies for 'ComfyUI_experiments'
# ## Install dependencies for 'comfyui-various'
# Requirement already satisfied: GitPython in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 1)) (3.1.45)
# Requirement already satisfied: PyGithub in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: matrix-nio in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (0.25.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (4.57.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 5)) (0.36.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 9)) (0.10.2)
# Requirement already satisfied: uv in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 10)) (0.9.5)
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/ComfyUI-Manager/requirements.txt (line 11)) (5.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 1)) (4.0.12)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: aiohttp~=3.10 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (3.13.1)
# Requirement already satisfied: aiofiles~=24.1 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (24.1.0)
# Requirement already satisfied: h11~=0.14 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: h2~=4.0 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (4.3.0)
# Requirement already satisfied: jsonschema~=4.14 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (4.25.1)
# Requirement already satisfied: unpaddedbase64~=2.1 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: pycryptodome~=3.10 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (3.23.0)
# Requirement already satisfied: aiohttp-socks~=0.8 in /usr/local/lib/python3.12/dist-packages (from matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (0.10.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 5)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 6)) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: python-socks<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from python-socks[asyncio]<3.0.0,>=2.4.3->aiohttp-socks~=0.8->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (2.7.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 1)) (5.0.2)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2~=4.0->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2~=4.0->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (4.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.14->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.14->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.14->matrix-nio->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (0.28.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from pynacl>=1.4.0->PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.14.0->PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.14.0->PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.14.0->PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2025.10.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub->-r custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2.23)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->-r custom_nodes/comfyui-detail-daemon/requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: ultralytics>=8.3.162 in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (8.3.222)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-subpack/requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-subpack/requirements.txt (line 4)) (4.12.0.88)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-subpack/requirements.txt (line 5)) (0.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (4.12.0.88)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (1.25.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (2.0.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics>=8.3.162->-r custom_nodes/comfyui-impact-subpack/requirements.txt (line 2)) (3.0.3)
# WARNING:root:
# WARN: The `COMFYUI_PATH` environment variable is not set. Assuming `/content/drive/MyDrive/ComfyUI` as the ComfyUI path.
# WARNING:root:
# WARN: The `COMFYUI_MODEL_PATH` environment variable is not set. Assuming `/content/drive/MyDrive/ComfyUI/models` as the ComfyUI path.
# Collecting git+https://github.com/facebookresearch/sam2 (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 10))
#   Cloning https://github.com/facebookresearch/sam2 to /tmp/pip-req-build-owk9ixz2
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/sam2 /tmp/pip-req-build-owk9ixz2
#   Resolved https://github.com/facebookresearch/sam2 to commit 2b90b9f5ceec907a1c18123530e92e794ad901a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: segment-anything in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 1)) (1.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 2)) (0.25.2)
# Requirement already satisfied: piexif in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (4.57.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 5)) (4.12.0.88)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 6)) (1.16.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 8)) (0.3.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui-impact-pack/requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 2)) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 2)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 2)) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 2)) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 2)) (0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 9)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 9)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 9)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.20.1 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (0.23.0+cu126)
# Requirement already satisfied: hydra-core>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: iopath>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (0.1.10)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from iopath>=0.1.10->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (3.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 4)) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.5.1->SAM-2==1.0->-r custom_nodes/comfyui-impact-pack/requirements.txt (line 10)) (3.0.3)
#
# WARN: The `COMFYUI_PATH` environment variable is not set. Assuming `/content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-impact-pack/../../` as the ComfyUI path.
#
# WARN: The `COMFYUI_MODEL_PATH` environment variable is not set. Assuming `/content/drive/MyDrive/ComfyUI/models` as the ComfyUI path.
# ### ComfyUI-Impact-Pack: Check dependencies
# ### ComfyUI-Impact-Pack: Check basic models
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui_essentials/requirements.txt (line 1)) (0.60.0)
# Requirement already satisfied: colour-science in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui_essentials/requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: rembg in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui_essentials/requirements.txt (line 3)) (2.0.67)
# Requirement already satisfied: pixeloe in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: transparent-background in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (1.3.4)
# ...
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->pixeloe->-r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->pixeloe->-r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->pixeloe->-r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->pixeloe->-r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->pixeloe->-r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->pixeloe->-r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg->-r custom_nodes/comfyui_essentials/requirements.txt (line 3)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg->-r custom_nodes/comfyui_essentials/requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg->-r custom_nodes/comfyui_essentials/requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg->-r custom_nodes/comfyui_essentials/requirements.txt (line 3)) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->rembg->-r custom_nodes/comfyui_essentials/requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg->-r custom_nodes/comfyui_essentials/requirements.txt (line 3)) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg->-r custom_nodes/comfyui_essentials/requirements.txt (line 3)) (0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations>=1.3.1->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations>=1.3.1->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations>=1.3.1->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.5.4->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.5.4->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.5.4->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.5.4->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->pixeloe->-r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.5.4->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (2.8)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm>=1.0.3->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->pixeloe->-r custom_nodes/comfyui_essentials/requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.5.4->transparent-background->-r custom_nodes/comfyui_essentials/requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: onnxruntime-gpu in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 2)) (1.23.2)
# Requirement already satisfied: requirements-parser in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: rembg in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 5)) (2.0.67)
# Requirement already satisfied: imageio_ffmpeg in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: rich_argparse in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 8)) (1.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 11)) (5.5.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 12)) (4.57.1)
# Requirement already satisfied: qrcode[pil] in /usr/local/lib/python3.12/dist-packages (from -r custom_nodes/comfy-mtb/requirements.txt (line 1)) (8.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->-r custom_nodes/comfy-mtb/requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->-r custom_nodes/comfy-mtb/requirements.txt (line 2)) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->-r custom_nodes/comfy-mtb/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->-r custom_nodes/comfy-mtb/requirements.txt (line 2)) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->-r custom_nodes/comfy-mtb/requirements.txt (line 2)) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->-r custom_nodes/comfy-mtb/requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: types-setuptools>=69.1.0 in /usr/local/lib/python3.12/dist-packages (from requirements-parser->-r custom_nodes/comfy-mtb/requirements.txt (line 3)) (80.9.0.20250822)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (4.25.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (4.12.0.88)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: pymatting in /usr/local/lib/python3.12/dist-packages (from rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (1.1.14)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (1.16.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r custom_nodes/comfy-mtb/requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r custom_nodes/comfy-mtb/requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfy-mtb/requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfy-mtb/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfy-mtb/requirements.txt (line 9)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfy-mtb/requirements.txt (line 9)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfy-mtb/requirements.txt (line 9)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r custom_nodes/comfy-mtb/requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->-r custom_nodes/comfy-mtb/requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->-r custom_nodes/comfy-mtb/requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime-gpu->-r custom_nodes/comfy-mtb/requirements.txt (line 2)) (10.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (4.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r custom_nodes/comfy-mtb/requirements.txt (line 12)) (2025.10.5)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (0.60.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu->-r custom_nodes/comfy-mtb/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting->rembg->-r custom_nodes/comfy-mtb/requirements.txt (line 5)) (0.43.0)
# [mtb install]  mtb doesn't need an install script anymore.
#
# All done

# %%
# #@title Environment Setup

from pathlib import Path

OPTIONS = {}

USE_GOOGLE_DRIVE = True  #@param {type:"boolean"}
UPDATE_COMFY_UI = True  #@param {type:"boolean"}
USE_COMFYUI_MANAGER = True  #@param {type:"boolean"}
INSTALL_CUSTOM_NODES_DEPENDENCIES = True  #@param {type:"boolean"}
OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI
OPTIONS['USE_COMFYUI_MANAGER'] = USE_COMFYUI_MANAGER
OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES'] = INSTALL_CUSTOM_NODES_DEPENDENCIES

current_dir = !pwd
WORKSPACE = f"{current_dir[0]}/ComfyUI"

if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /

    from google.colab import drive
    drive.mount('/content/drive')

    WORKSPACE = "/content/drive/MyDrive/ComfyUI"
    # %cd /content/drive/MyDrive

![ ! -d $WORKSPACE ] && echo -= Initial setup ComfyUI =- && git clone https://github.com/comfyanonymous/ComfyUI
# %cd $WORKSPACE

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo -= Updating ComfyUI =-

  # Correction of the issue of permissions being deleted on Google Drive.
  ![ -f ".ci/nightly/update_windows/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/nightly/update_windows/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/nightly/windows_base_files/run_nvidia_gpu.bat" ] && chmod 755 .ci/nightly/windows_base_files/run_nvidia_gpu.bat
  ![ -f ".ci/update_windows/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/update_windows/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/update_windows_cu118/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/update_windows_cu118/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/update_windows/update.py" ] && chmod 755 .ci/update_windows/update.py
  ![ -f ".ci/update_windows/update_comfyui.bat" ] && chmod 755 .ci/update_windows/update_comfyui.bat
  ![ -f ".ci/update_windows/README_VERY_IMPORTANT.txt" ] && chmod 755 .ci/update_windows/README_VERY_IMPORTANT.txt
  ![ -f ".ci/update_windows/run_cpu.bat" ] && chmod 755 .ci/update_windows/run_cpu.bat
  ![ -f ".ci/update_windows/run_nvidia_gpu.bat" ] && chmod 755 .ci/update_windows/run_nvidia_gpu.bat

  # !git pull

# !echo -= Install dependencies =-
# !pip3 install accelerate
# !pip3 install einops transformers>=4.28.1 safetensors>=0.4.2 aiohttp pyyaml Pillow scipy tqdm psutil tokenizers>=0.13.3
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip3 install torchsde
# !pip3 install kornia>=0.7.1 spandrel soundfile sentencepiece

if OPTIONS['USE_COMFYUI_MANAGER']:
  # %cd custom_nodes

  # Correction of the issue of permissions being deleted on Google Drive.
  ![ -f "ComfyUI-Manager/check.sh" ] && chmod 755 ComfyUI-Manager/check.sh
  ![ -f "ComfyUI-Manager/scan.sh" ] && chmod 755 ComfyUI-Manager/scan.sh
  ![ -f "ComfyUI-Manager/node_db/dev/scan.sh" ] && chmod 755 ComfyUI-Manager/node_db/dev/scan.sh
  ![ -f "ComfyUI-Manager/node_db/tutorial/scan.sh" ] && chmod 755 ComfyUI-Manager/node_db/tutorial/scan.sh
  ![ -f "ComfyUI-Manager/scripts/install-comfyui-venv-linux.sh" ] && chmod 755 ComfyUI-Manager/scripts/install-comfyui-venv-linux.sh
  ![ -f "ComfyUI-Manager/scripts/install-comfyui-venv-win.bat" ] && chmod 755 ComfyUI-Manager/scripts/install-comfyui-venv-win.bat

  ![ ! -d ComfyUI-Manager ] && echo -= Initial setup ComfyUI-Manager =- && git clone https://github.com/ltdrdata/ComfyUI-Manager
  # %cd ComfyUI-Manager
  # !git pull

# %cd $WORKSPACE

if OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES']:
  # !echo -= Install custom nodes dependencies =-
  # !pip install GitPython
  # !python custom_nodes/ComfyUI-Manager/cm-cli.py restore-dependencies

# %% [markdown]
# ### Run ComfyUI with cloudflared (Recommended Way)

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

import subprocess
import threading
import time
import socket
import urllib.request

# !pip install av
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
# Out:
# Using pytorch attention in VAE
# Using pytorch attention in VAE
# VAE load device: cuda:0, offload device: cpu, dtype: torch.float32
# Requested to load SDXLClipModel
# loaded completely 9.5367431640625e+25 1560.802734375 True
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cuda:0, dtype: torch.float16
# loaded diffusion model directly to GPU
# Requested to load SDXL
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100% 8/8 [00:11<00:00,  1.41s/it]
# Requested to load AutoencoderKL
# loaded completely 353.1942596435547 319.11416244506836 True
# Prompt executed in 279.96 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.45s/it]
# Prompt executed in 14.75 seconds
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# model weight dtype torch.float16, manual cast: None
# model_type EPS
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# Using pytorch attention in VAE
# Using pytorch attention in VAE
# VAE load device: cuda:0, offload device: cpu, dtype: torch.float32
# Requested to load SDXLClipModel
# loaded completely 9.5367431640625e+25 1560.802734375 True
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cuda:0, dtype: torch.float16
# loaded diffusion model directly to GPU
# Requested to load SDXL
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100% 8/8 [00:10<00:00,  1.37s/it]
# Requested to load AutoencoderKL
# loaded completely 353.1942596435547 319.11416244506836 True
# Prompt executed in 283.68 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.40s/it]
# Prompt executed in 14.14 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.44s/it]
# Prompt executed in 14.45 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.44s/it]
# Prompt executed in 14.53 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.42s/it]
# Prompt executed in 14.36 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.44s/it]
# Prompt executed in 14.81 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.49s/it]
# Prompt executed in 15.19 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:12<00:00,  1.52s/it]
# Prompt executed in 15.26 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.49s/it]
# Prompt executed in 14.93 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.76 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.46s/it]
# Prompt executed in 14.69 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.79 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 14.82 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 15.22 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 15.41 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.88 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 14.86 seconds
# loaded completely 8496.58957748413 1560.802734375 True
#  38% 3/8 [00:04<00:07,  1.58s/it]got prompt
#  50% 4/8 [00:06<00:06,  1.58s/it]Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# 100% 8/8 [00:11<00:00,  1.48s/it]
# got prompt
# Prompt executed in 15.00 seconds
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# model weight dtype torch.float16, manual cast: None
# model_type EPS
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# Using pytorch attention in VAE
# Using pytorch attention in VAE
# VAE load device: cuda:0, offload device: cpu, dtype: torch.float32
# Requested to load SDXLClipModel
# loaded completely 9.5367431640625e+25 1560.802734375 True
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cuda:0, dtype: torch.float16
# loaded diffusion model directly to GPU
# Requested to load SDXL
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100% 8/8 [00:11<00:00,  1.38s/it]
# Requested to load AutoencoderKL
# loaded completely 353.1942596435547 319.11416244506836 True
# Prompt executed in 340.98 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.41s/it]
# Prompt executed in 14.17 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.44s/it]
# Prompt executed in 14.55 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.46s/it]
# Prompt executed in 14.64 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.75 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 14.95 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 15.18 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.92 seconds
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# model weight dtype torch.float16, manual cast: None
# model_type EPS
# got prompt
# Using pytorch attention in VAE
# Using pytorch attention in VAE
# VAE load device: cuda:0, offload device: cpu, dtype: torch.float32
# Requested to load SDXLClipModel
# loaded completely 9.5367431640625e+25 1560.802734375 True
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cuda:0, dtype: torch.float16
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# loaded diffusion model directly to GPU
# Requested to load SDXL
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100% 8/8 [00:11<00:00,  1.38s/it]
# Requested to load AutoencoderKL
# loaded completely 353.1942596435547 319.11416244506836 True
# Prompt executed in 291.76 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.42s/it]
# Prompt executed in 14.37 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.45s/it]
# Prompt executed in 14.65 seconds
# loaded completely 8496.58957748413 1560.802734375 True
#  88% 7/8 [00:11<00:01,  1.60s/it]got prompt
# 100% 8/8 [00:11<00:00,  1.50s/it]
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# Prompt executed in 15.01 seconds
# loaded completely 8496.58957748413 1560.802734375 True
#  50% 4/8 [00:06<00:06,  1.63s/it]got prompt
#  75% 6/8 [00:09<00:03,  1.63s/it]Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# 100% 8/8 [00:12<00:00,  1.53s/it]
# Prompt executed in 15.38 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.49s/it]
# Prompt executed in 15.07 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.97 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.46s/it]
# Prompt executed in 14.92 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.82 seconds
# got prompt
# loaded completely 8496.58957748413 1560.802734375 True
#  12% 1/8 [00:01<00:10,  1.54s/it]Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
#  75% 6/8 [00:09<00:03,  1.58s/it]got prompt
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# Prompt executed in 14.92 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 14.88 seconds
# loaded completely 8496.58957748413 1560.802734375 True
#  75% 6/8 [00:09<00:03,  1.57s/it]got prompt
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# Prompt executed in 14.84 seconds
# loaded completely 8496.58957748413 1560.802734375 True
#  38% 3/8 [00:04<00:07,  1.57s/it]got prompt
#  62% 5/8 [00:07<00:04,  1.57s/it]Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.92 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 15.28 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.79 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.81 seconds
# loaded completely 8496.58957748413 1560.802734375 True
#  12% 1/8 [00:01<00:10,  1.55s/it]got prompt
#  38% 3/8 [00:04<00:07,  1.57s/it]Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# 100% 8/8 [00:11<00:00,  1.47s/it]
# got prompt
# Prompt executed in 15.12 seconds
# loaded completely 8496.58957748413 1560.802734375 True
#   0% 0/8 [00:00<?, ?it/s]Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 14.94 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 15.19 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.47s/it]
# Prompt executed in 14.86 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 15.09 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 14.82 seconds
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.48s/it]
# Prompt executed in 14.90 seconds
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.44s/it]
# Prompt executed in 14.73 seconds
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.44s/it]
# Prompt executed in 14.72 seconds
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.42s/it]
# Prompt executed in 14.38 seconds
# got prompt
# Failed to validate prompt for output 144:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 144:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 140:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 140:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 146:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 146:
#   - Required input is missing: images
# Output will be ignored
# Failed to validate prompt for output 142:
# * (prompt):
#   - Required input is missing: images
# * SaveImage 142:
#   - Required input is missing: images
# Output will be ignored
# loaded completely 8496.58957748413 1560.802734375 True
# 100% 8/8 [00:11<00:00,  1.38s/it]
# Prompt executed in 14.10 seconds
